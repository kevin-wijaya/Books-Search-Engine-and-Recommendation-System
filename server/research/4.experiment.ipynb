# %%
import os, sys ; ROOT = os.path.dirname(os.getcwd())
sys.path.insert(0, ROOT) if ROOT not in sys.path else None

# %%
# import libraries
from src.modeling import BM25
from src.preprocessing import Preprocessing
from rank_bm25 import BM25Okapi
import pandas as pd

# %%
# read CSV file
books = pd.read_pickle(os.path.join(ROOT, 'data', 'prepared_books.pkl'))
books.info()
books.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79436 entries, 0 to 271369
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   isbn                   79436 non-null  object
#  1   title                  79436 non-null  object
#  2   author                 79436 non-null  object
#  3   year_of_publication    79436 non-null  object
#  4   publisher              79436 non-null  object
#  5   description            79436 non-null  object
#  6   title_processed        79436 non-null  object
#  7   description_processed  79436 non-null  object
# dtypes: object(8)
# memory usage: 5.5+ MB
#          isbn                title                author year_of_publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  publisher                                        description  \
# 0  Oxford University Press  Featuring the authors' extensive, clear, and f...
# 1    HarperFlamingo Canada  It is the year 1934, and in a small town in Ca...
#
#           title_processed                              description_processed
# 0  [classical, mythology]  [featuring, the, authors, extensive, clear, an...
# 1         [clara, callan]  [it, is, the, year, 1934, and, in, a, small, t...

# %%
# initialize BM25 with tokenized documents
bm25_title = BM25Okapi(books['title_processed'].tolist())
bm25_description = BM25Okapi(books['description_processed'].tolist())

# %%
# compute BM25 scores for the query
query = 'harry potter prisoner azkaba'
tokenized_query = Preprocessing().fit_transform(query)

print(tokenized_query)
scores_title = bm25_title.get_scores(tokenized_query)
scores_description = bm25_description.get_scores(tokenized_query)

# define weights
weight_title = 0.8
weight_description = 0.2

# combine BM25 scores with feature weights
books['bm25_score'] = (weight_title * scores_title) + (weight_description * scores_description)

# sort by BM25 score
df_sorted = books.sort_values(by='bm25_score', ascending=False)

# display results
df_sorted[['title', 'description', 'bm25_score']].head(10)
# Out:
# ['harry', 'potter', 'prisoner', 'azkaba']
#                                                    title  \
# 20166  Harry Potter and the Prisoner of Azkaban Color...
# 6330   Harry Potter and the Prisoner of Azkaban (Book 3)
# 3839   Harry Potter and the Prisoner of Azkaban (Book 3)
# 52580                              We Love Harry Potter!
# 34082  Harry Potter and the Prisoner of Azkaban (Book...
# 77384  Harry Potter and the Sorcerer's Stone (Harry P...
# 2143   Harry Potter and the Sorcerer's Stone (Harry P...
# 28425  Harry Potter and the Prisoner of Azkaban (Book...
# 34540                    Harry Potter Und Der Feuerkelch
# 41882               Harry Potter Collector's Value Guide
#
#                                              description  bm25_score
# 20166  Three times the scares, three times the tears,...   19.182695
# 6330   For twelve long years, the dread fortress of A...   17.136954
# 3839   For twelve long years, the dread fortress of A...   16.714728
# 52580  Harry Potter-by now the name is surely as magi...   16.326613
# 34082  Running time: 11 hrs., 48 mins.\n\nFor twelve ...   16.246581
# 77384  Harry Potter has no idea how famous he is. Tha...   16.122784
# 2143   Harry Potter has no idea how famous he is. Tha...   16.122784
# 28425  Read by Jim Dale\nRunning time: 11 hrs., 48 mi...   15.449513
# 34540  The fourth book in the Harry Potter series tra...   15.396376
# 41882  Lists prices and values of Harry Potter mercha...   15.165872

# %%
# testing the BM25 class that utilizes BM25Okapi and multi-feature weightings
bm25 = BM25(
    corpus_title=books['title_processed'].tolist(), 
    corpus_description=books['description_processed'].tolist(),
    weights=[0.8, 0.2]
)

# %%
# get scores #1
books['bm25_score_2'] = bm25.similarity(Preprocessing().fit_transform('we love harry potter'), True)
books_scores = books.sort_values(by='bm25_score_2', ascending=False)
books_scores.head(5)
# Out:
#              isbn                                              title  \
# 52580  031226481X                              We Love Harry Potter!
# 2143   059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 77384  059035342x  Harry Potter and the Sorcerer's Stone (Harry P...
# 34540  3551551936                    Harry Potter Und Der Feuerkelch
# 41882  1585980730               Harry Potter Collector's Value Guide
#
#                       author year_of_publication               publisher  \
# 52580           Sharon Moore                1999      St. Martin's Press
# 2143           J. K. Rowling                1999  Arthur A. Levine Books
# 77384          J. K. Rowling                1999  Arthur A. Levine Books
# 34540      Joanne K. Rowling                1999     Carlsen Verlag GmbH
# 41882  CheckerBee Publishing                2000   CheckerBee Publishing
#
#                                              description  \
# 52580  Harry Potter-by now the name is surely as magi...
# 2143   Harry Potter has no idea how famous he is. Tha...
# 77384  Harry Potter has no idea how famous he is. Tha...
# 34540  The fourth book in the Harry Potter series tra...
# 41882  Lists prices and values of Harry Potter mercha...
#
#                                          title_processed  \
# 52580                          [we, love, harry, potter]
# 2143   [harry, potter, and, the, sorcerers, stone, ha...
# 77384  [harry, potter, and, the, sorcerers, stone, ha...
# 34540              [harry, potter, und, der, feuerkelch]
# 41882          [harry, potter, collectors, value, guide]
#
#                                    description_processed  bm25_score  \
# 52580  [harry, potterby, now, the, name, is, surely, ...   16.326613
# 2143   [harry, potter, has, no, idea, how, famous, he...   16.122784
# 77384  [harry, potter, has, no, idea, how, famous, he...   16.122784
# 34540  [the, fourth, book, in, the, harry, potter, se...   15.396376
# 41882  [lists, prices, and, values, of, harry, potter...   15.165872
#
#        bm25_score_2
# 52580      0.998417
# 2143       0.610303
# 77384      0.610303
# 34540      0.589680
# 41882      0.579666

# %%
# get scores #2
books['bm25_score_2'] = bm25.similarity(Preprocessing().fit_transform('harry potter collectors value guide'), True)
books_scores = books.sort_values(by='bm25_score_2', ascending=False)
books_scores.head(5)
# Out:
#              isbn                                              title  \
# 41882  1585980730               Harry Potter Collector's Value Guide
# 47847  1888914777        Charming Tails 2000 Collector's Value Guide
# 76486  188891419X  Beanie Babies Spring 1998 Collector's Value Guide
# 52580  031226481X                              We Love Harry Potter!
# 2143   059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
#
#                          author year_of_publication  \
# 41882     CheckerBee Publishing                2000
# 47847     CheckerBee Publishing                2000
# 76486  Collectors Publishing Co                1998
# 52580              Sharon Moore                1999
# 2143              J. K. Rowling                1999
#
#                               publisher  \
# 41882             CheckerBee Publishing
# 47847             CheckerBee Publishing
# 76486  The College of Estate Management
# 52580                St. Martin's Press
# 2143             Arthur A. Levine Books
#
#                                              description  \
# 41882  Lists prices and values of Harry Potter mercha...
# 47847  Fans of the Charming Tails line can easily kee...
# 76486  Tys Beanie Babies have captured the hearts of ...
# 52580  Harry Potter-by now the name is surely as magi...
# 2143   Harry Potter has no idea how famous he is. Tha...
#
#                                          title_processed  \
# 41882          [harry, potter, collectors, value, guide]
# 47847  [charming, tails, 2000, collectors, value, guide]
# 76486  [beanie, babies, spring, 1998, collectors, val...
# 52580                          [we, love, harry, potter]
# 2143   [harry, potter, and, the, sorcerers, stone, ha...
#
#                                    description_processed  bm25_score  \
# 41882  [lists, prices, and, values, of, harry, potter...   15.165872
# 47847  [fans, of, the, charming, tails, line, can, ea...    0.000000
# 76486  [tys, beanie, babies, have, captured, the, hea...    0.000000
# 52580  [harry, potterby, now, the, name, is, surely, ...   16.326613
# 2143   [harry, potter, has, no, idea, how, famous, he...   16.122784
#
#        bm25_score_2
# 41882      0.954703
# 47847      0.624597
# 76486      0.558359
# 52580      0.522343
# 2143       0.505310

# %%
# get scores #3
books['bm25_score_2'] = bm25.similarity(Preprocessing().fit_transform('tet'), True)
books_scores = books.sort_values(by='bm25_score_2', ascending=False)
books_scores.head(5)
# Out:
#              isbn                                         title  \
# 28599  002930380X     AFTER TET : THE BLOODIEST YEAR IN VIETNAM
# 24687  067156787X                 A TIME OF WAR : A TIME OF WAR
# 70368  0679760237  In Pharaoh's Army : Memories of the Lost War
# 38660  0142003395                                The Silent Men
# 23283  0312876610                                      Vivienne
#
#                      author year_of_publication      publisher  \
# 28599     Ronald H. Spector                1992     Free Press
# 24687      Michael Peterson                1996         Pocket
# 70368          TOBIAS WOLFF                1995        Vintage
# 38660  Richard H. Dickinson                2003  Penguin Books
# 23283          Richard Hoyt                2000          Forge
#
#                                              description  \
# 28599  Recounts the experience of American soldiers i...
# 24687  In the months before the Tet Offensive, season...
# 70368  Whether he is evoking the blind carnage of the...
# 38660  Jackson Monroe is the finest American sniper i...
# 23283  It is 1968, the end of Tet, the Chinese New Ye...
#
#                                          title_processed  \
# 28599    [after, tet, the, bloodiest, year, in, vietnam]
# 24687               [a, time, of, war, a, time, of, war]
# 70368  [in, pharaohs, army, memories, of, the, lost, ...
# 38660                                 [the, silent, men]
# 23283                                         [vivienne]
#
#                                    description_processed  bm25_score  \
# 28599  [recounts, the, experience, of, american, sold...         0.0
# 24687  [in, the, months, before, the, tet, offensive,...         0.0
# 70368  [whether, he, is, evoking, the, blind, carnage...         0.0
# 38660  [jackson, monroe, is, the, finest, american, s...         0.0
# 23283  [it, is, 1968, the, end, of, tet, the, chinese...         0.0
#
#        bm25_score_2
# 28599      0.800000
# 24687      0.200000
# 70368      0.176574
# 38660      0.123721
# 23283      0.098514

# %%
# get scores #4
books['bm25_score_2'] = bm25.similarity(Preprocessing().fit_transform('gg'), True)
books_scores = books.sort_values(by='bm25_score_2', ascending=False)
books_scores.head(10)
# Out:
#              isbn                                       title  \
# 12547  0671628410                                     Why Me?
# 0      0195153448                         Classical Mythology
# 52992  0758204531                     Standing in the Shadows
# 52991  1843605546                              A Mutual Favor
# 52990  0312987293                     You've Got a Hold On Me
# 52989  0312989970  The Midnight Hour (A Madaris Family Novel)
# 52988  0743457447                             Hard Lovin' Man
# 52987  0441081223                            Gnome Man's Land
# 52986  0385510500                          Faithful : A Novel
# 52985  0451408136                                Diamond Rain
#
#                    author year_of_publication                publisher  \
# 12547       Ellen Conford                1987             Pocket Books
# 0      Mark P. O. Morford                2002  Oxford University Press
# 52992     Shannon McKenna                2003                    BRAVA
# 52991          Ann Jacobs                2002            Ellora's Cave
# 52990        Tamara Sneed                2004  St. Martin's Paperbacks
# 52989      Brenda Jackson                2004  St. Martin's Paperbacks
# 52988      Lorraine Heath                2003              Pocket Star
# 52987     Esther Friesner                1991                Ace Books
# 52986     DAVITT SIGERSON                2004            Nan A. Talese
# 52985      Constance Laux                1999                    Topaz
#
#                                              description  \
# 12547  Talk about girl trouble!\nSince G.G. Graffman ...
# 0      Featuring the authors' extensive, clear, and f...
# 52992  Ex-FBI agent Connor McCloud must gain the trus...
# 52991  Two good friends, two thorny problems. Kurt ne...
# 52990  It takes alot for Assistant D.A. Amelia Farrow...
# 52989  Sexy, dangerous, unforgettable. . .the Madaris...
# 52988  Ten years after leaving her former lover Jack ...
# 52987  When a hole in the fabric of the universe rips...
# 52986  Risky, fiercely erotic and deeply touching, Da...
# 52985  The glitter and pomp of Queen Victoria's Diamo...
#
#                                         title_processed  \
# 12547                                         [why, me]
# 0                                [classical, mythology]
# 52992                      [standing, in, the, shadows]
# 52991                                [a, mutual, favor]
# 52990                     [youve, got, a, hold, on, me]
# 52989  [the, midnight, hour, a, madaris, family, novel]
# 52988                                [hard, lovin, man]
# 52987                               [gnome, mans, land]
# 52986                              [faithful, a, novel]
# 52985                                   [diamond, rain]
#
#                                    description_processed  bm25_score  \
# 12547  [talk, about, girl, trouble, since, gg, graffm...         0.0
# 0      [featuring, the, authors, extensive, clear, an...         0.0
# 52992  [exfbi, agent, connor, mccloud, must, gain, th...         0.0
# 52991  [two, good, friends, two, thorny, problems, ku...         0.0
# 52990  [it, takes, alot, for, assistant, da, amelia, ...         0.0
# 52989  [sexy, dangerous, unforgettable, the, madaris,...         0.0
# 52988  [ten, years, after, leaving, her, former, love...         0.0
# 52987  [when, a, hole, in, the, fabric, of, the, univ...         0.0
# 52986  [risky, fiercely, erotic, and, deeply, touchin...         0.0
# 52985  [the, glitter, and, pomp, of, queen, victorias...         0.0
#
#        bm25_score_2
# 12547           0.2
# 0               0.0
# 52992           0.0
# 52991           0.0
# 52990           0.0
# 52989           0.0
# 52988           0.0
# 52987           0.0
# 52986           0.0
# 52985           0.0
